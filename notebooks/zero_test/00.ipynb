# %%
from eshmun.models.zero.models import EshmunZeroModel, EshmunForMaskedLM
from eshmun.models.zero.configuration import EshmunZeroConfig

# %%
config = EshmunZeroConfig(hidden_size=64, intermediate_size=256, num_attention_heads=8)

# %%
config
# Out:
# EshmunZeroConfig {
#   "alpha_init": 0.0,
#   "attention_probs_dropout_prob": 0.1,
#   "embedding_size": 4096,
#   "hidden_act": "silu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 64,
#   "initializer_range": 0.02,
#   "intermediate_size": 256,
#   "is_decoder": false,
#   "layer_norm_eps": 1e-12,
#   "local_window_size": 12,
#   "max_position_embeddings": 514,
#   "model_type": "eshmun_zero",
#   "num_attention_heads": 8,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "5.3.0",
#   "use_cache": true,
#   "vocab_size": 25
# }

# %%
model = EshmunZeroModel(config)

# %%
model
# Out:
# EshmunZeroModel(
#   (embeddings): EshmunEmbeddings(
#     (wte): Embedding(25, 4096, padding_idx=0)
#     (wpe): Embedding(514, 4096)
#     (layer_norm): LayerNorm((4096,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (tokens_to_hidden): Linear(in_features=4096, out_features=64, bias=False)
#   (encoder): EshmunEncoder(
#     (layers): ModuleList(
#       (0-11): 12 x EshmunLayer(
#         (attention): EshmunGatedAttention(
#           (local_attn): EshmunLocalSelfAttention(
#             (q): Linear(in_features=64, out_features=64, bias=True)
#             (k): Linear(in_features=64, out_features=64, bias=True)
#             (v): Linear(in_features=64, out_features=64, bias=True)
#             (out_proj): Linear(in_features=64, out_features=64, bias=True)
#             (attn_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (global_attn): EshmunGlobalSelfAttention(
#             (q): Linear(in_features=64, out_features=64, bias=True)
#             (k): Linear(in_features=64, out_features=64, bias=True)
#             (v): Linear(in_features=64, out_features=64, bias=True)
#             (out_proj): Linear(in_features=64, out_features=64, bias=True)
#             (attn_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (layer_norm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ffn): EshmunFeedForward(
#           (dense_in): Linear(in_features=64, out_features=256, bias=True)
#           (dense_out): Linear(in_features=256, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (pooler): EshmunPooler(
#     (dense): Linear(in_features=64, out_features=64, bias=True)
#     (activation): Tanh()
#   )
# )
